# %% [markdown]
# Domain Adaptation/Generalisierung ohne distance_loss (mit/ohne Augmentation)

# %%
from __future__ import print_function

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from keras.datasets import mnist
import tensorflow_datasets as tfds
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras import backend as K
from scipy import ndimage
import matplotlib.pyplot as plt
import numpy as np
import h5py
import pandas as pd
from skimage.transform import resize
from skimage.color import gray2rgb
from sklearn.utils import shuffle
from numpy import load
from numpy import save

batch_size = 50
num_classes = 10
num_epochs = 20
num_train_samples = 1000
val_size = 5000
loadModelBool = False
saveModelBool = False
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip "drive/My Drive/Data/mnist_m.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002655.png
#   inflating: mnist_m/mnist_m_test/00004224.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00004224.png
#   inflating: mnist_m/mnist_m_test/00002866.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002866.png
#   inflating: mnist_m/mnist_m_test/00008393.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00008393.png
#   inflating: mnist_m/mnist_m_test/00000917.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000917.png
#   inflating: mnist_m/mnist_m_test/00008387.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00008387.png
#   inflating: mnist_m/mnist_m_test/00000903.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000903.png
#   inflating: mnist_m/mnist_m_test/00002872.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002872.png
#   inflating: mnist_m/mnist_m_test/00007922.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007922.png
#   inflating: mnist_m/mnist_m_test/00000095.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000095.png
#   inflating: mnist_m/mnist_m_test/00002682.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002682.png
#   inflating: mnist_m/mnist_m_test/00004595.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00004595.png
#   inflating: mnist_m/mnist_m_test/00005853.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00005853.png
#   inflating: mnist_m/mnist_m_test/00006382.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00006382.png
#   inflating: mnist_m/mnist_m_test/00007088.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007088.png
#   inflating: mnist_m/mnist_m_test/00006396.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00006396.png
#   inflating: mnist_m/mnist_m_test/00004581.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00004581.png
#   inflating: mnist_m/mnist_m_test/00005847.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00005847.png
#   inflating: mnist_m/mnist_m_test/00003588.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00003588.png
#   inflating: mnist_m/mnist_m_test/00002696.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002696.png
#   inflating: mnist_m/mnist_m_test/00007936.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007936.png
#   inflating: mnist_m/mnist_m_test/00000081.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000081.png
#   inflating: mnist_m/mnist_m_test/00008152.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00008152.png
#   inflating: mnist_m/mnist_m_test/00007261.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007261.png
#   inflating: mnist_m/mnist_m_test/00001610.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00001610.png
#   inflating: mnist_m/mnist_m_test/00005476.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00005476.png
#   inflating: mnist_m/mnist_m_test/00002319.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00002319.png
#   inflating: mnist_m/mnist_m_test/00003007.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00003007.png
#   inflating: mnist_m/mnist_m_test/00004768.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00004768.png
#   inflating: mnist_m/mnist_m_test/00003761.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00003761.png
#   inflating: mnist_m/mnist_m_test/00005310.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00005310.png
#   inflating: mnist_m/mnist_m_test/00006619.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00006619.png
#   inflating: mnist_m/mnist_m_test/00001176.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00001176.png
#   inflating: mnist_m/mnist_m_test/00000268.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000268.png
#   inflating: mnist_m/mnist_m_test/00008634.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00008634.png
#   inflating: mnist_m/mnist_m_test/00007507.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007507.png
#   inflating: mnist_m/mnist_m_test/00001162.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00001162.png
#   inflating: mnist_m/mnist_m_test/00008620.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00008620.png
#   inflating: mnist_m/mnist_m_test/00007513.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00007513.png
#   inflating: mnist_m/mnist_m_test/00003775.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00003775.png
#   inflating: mnist_m/mnist_m_test/00005304.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00005304.png
#   inflating: mnist_m/mnist_m_test/00005462.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00
png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00006281.png
#   inflating: mnist_m/mnist_m_test/00000828.png
#   inflating: __MACOSX/mnist_m/mnist_m_test/._00000828.png

# %%
def load_svhn_data(path, val_size, num_classes):
    with h5py.File(path+'/train.hdf5', 'r') as f:
        shape = f["X"].shape
        x_train = f["X"][:shape[0]-val_size]
        y_train = f["Y"][:shape[0]-val_size].flatten()
        x_val = f["X"][shape[0]-val_size:]
        y_val = f["Y"][shape[0] - val_size:].flatten()

    with h5py.File(path+'/test.hdf5', 'r') as f:
        x_test = f["X"][:]
        y_test = f["Y"][:].flatten()

    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_val = keras.utils.to_categorical(y_val, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)

    return (x_train, y_train), (x_val, y_val), (x_test, y_test)

def reshapeImages(images):
    images_redone = []
    for image in images:
        image = resize(image,(32,32))
        image = gray2rgb(image)
        images_redone.append(image)
    images = np.asarray(images_redone)
    images = images.reshape(images.shape[0], 32, 32, 3)
    images = images.astype('float32')
    images /= 255
    print(images.shape[0], 'samples')
    return (images)

def show_history(history):
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train_accuracy', 'test_accuracy'], loc='best')
    plt.show()
    
def show_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('#f Iterations')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
def read_labeled_image_list(image_list_file):
    """Reads a .txt file containing pathes and labeles
    Args:
       image_list_file: a .txt file with one /path/to/image per line
       label: optionally, if set label will be pasted after each line
    Returns:
       List with all filenames in file image_list_file
    """
    f = open(image_list_file, 'r')
    filenames = []
    labels = []
    for line in f:
        filename, label = line[:-1].split(' ')
        filenames.append(filename)
        labels.append(int(label))
    return filenames, labels

# %%
# Reads pfathes of images together with their labels
image_list, label_list = read_labeled_image_list("mnist_m/mnist_m_train_labels.txt")
mnist_m_train = pd.DataFrame(np.column_stack([image_list, label_list]), 
                               columns=['image_id', 'label'])
# data generators:
datagen = ImageDataGenerator(rescale=1./255)
train_generator_mnistm = datagen.flow_from_dataframe(
    dataframe=mnist_m_train,
    directory="mnist_m/mnist_m_train/",
    x_col='image_id',
    y_col='label',
    target_size=(32,32),
    batch_size=mnist_m_train.shape[0]
)
x_mnistm_train, y_mnistm_train = train_generator_mnistm.next()
# Out:
# Found 59001 validated image filenames belonging to 10 classes.

# %%
# Reads pfathes of images together with their labels
image_list, label_list = read_labeled_image_list("mnist_m/mnist_m_test_labels.txt")
mnist_m_test = pd.DataFrame(np.column_stack([image_list, label_list]), 
                               columns=['image_id', 'label'])
# data generators:
datagen = ImageDataGenerator(rescale=1./255)
test_generator_mnistm = datagen.flow_from_dataframe(
    dataframe=mnist_m_test,
    directory="mnist_m/mnist_m_test/",
    x_col='image_id',
    y_col='label',
    target_size=(32,32),
    batch_size=mnist_m_test.shape[0]
)
x_mnistm_test, y_mnistm_test = test_generator_mnistm.next()
# Out:
# Found 9001 validated image filenames belonging to 10 classes.

# %%
# the data, split between train and test sets
# The full `train` split and the full `test` split as two distinct datasets.
(x_train_svhn, y_train_svhn), (x_val_svhn, y_val_svhn), (x_test_svhn, y_test_svhn) = load_svhn_data('drive/My Drive/Data/svhn', val_size, num_classes)
(x_train_mnist, y_train_mnist), (x_test_mnist, y_test_mnist) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
nr_of_nrs_mnistm = 200
y_train_mnistm_nrs = np.argmax(y_mnistm_train, axis=-1)
x_train_mnistm = x_mnistm_train[y_train_mnistm_nrs == 0][:nr_of_nrs_mnistm]
y_train_mnistm = y_mnistm_train[y_train_mnistm_nrs == 0][:nr_of_nrs_mnistm]
for i in range(1, 10):
  x_train_nr = x_mnistm_train[y_train_mnistm_nrs == i][:nr_of_nrs_mnistm]
  y_train_nr = y_mnistm_train[y_train_mnistm_nrs == i][:nr_of_nrs_mnistm]
  x_train_mnistm = np.vstack((x_train_mnistm, x_train_nr))
  y_train_mnistm = np.vstack((y_train_mnistm, y_train_nr))

x_train_mnistm, y_train_mnistm = shuffle(x_train_mnistm, y_train_mnistm)

# %%
x_test_mnist = reshapeImages(x_test_mnist)

# convert class vectors to binary class matrices
y_test_mnist = keras.utils.to_categorical(y_test_mnist, num_classes)
# Out:
# 10000 samples

# %%
input1 = keras.layers.Input(shape=(32,32,3))
conv1 = keras.layers.Conv2D(32, (3, 3), activation='relu')(input1)
conv2 = keras.layers.Conv2D(32, (3, 3), activation='relu')(conv1)
maxpool1 = keras.layers.MaxPooling2D((2, 2))(conv2)
dropout1 = keras.layers.Dropout(0.1)(maxpool1)
conv3 = keras.layers.Conv2D(64, (3, 3), activation='relu')(dropout1)
conv4 = keras.layers.Conv2D(64, (3, 3), activation='relu')(conv3)
maxpool2 = keras.layers.MaxPooling2D((2, 2))(conv4)
flatten = keras.layers.Flatten()(maxpool2)
dense1 = keras.layers.Dense(50, activation='relu')(flatten)
dense2 = keras.layers.Dense(20, activation='relu')(dense1)
output = keras.layers.Dense(num_classes, activation='softmax')(dense2)

model = keras.Model(inputs=input1, outputs=[dense2,output])

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                32020
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# =================================================================
# Total params: 97,798
# Trainable params: 97,798
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train_svhn_ones = np.ones((y_train_svhn.shape[0],1))
y_train_svhn_ = np.hstack((y_train_svhn, y_train_svhn_ones))
y_train_mnist_zeros = np.zeros((y_train_mnistm.shape[0],1))
y_mnistm_train_ = np.hstack((y_train_mnistm, y_train_mnist_zeros))

# %%
# Instantiate an optimizer to train the model.
optimizer = tf.compat.v1.train.AdamOptimizer()
# Instantiate a loss function.
loss_cc = keras.losses.CategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.CategoricalAccuracy()
val_acc_metric = keras.metrics.CategoricalAccuracy()

# Prepare the training datasets
train_dataset = tf.data.Dataset.from_tensor_slices((np.concatenate([x_train_svhn, x_train_mnistm], axis=0), np.concatenate([y_train_svhn_,y_mnistm_train_],axis=0)))
train_dataset = train_dataset.shuffle(buffer_size=200000).batch(batch_size)

# Prepare the validation dataset.
val_dataset = tf.data.Dataset.from_tensor_slices((np.concatenate([x_val_svhn, x_mnistm_test], axis=0), np.concatenate([y_val_svhn,y_mnistm_test],axis=0)))
val_dataset = val_dataset.batch(batch_size)

# %%
def distance_loss(predictions, y, predictions_target, y_target, classes_y):
    def some_function(tensor):
      y_source = tensor[1]
      equal =  tf.math.equal(y_source, y_target)
      equal_all = tf.reduce_all(equal, axis=1)
      contains = tf.boolean_mask(predictions_target, equal_all)
      distance = tf.sqrt(tf.reduce_sum(tf.square(tf.subtract(tensor[0], contains)), axis=1))
      # nearest k points
      closest_distance,_ = tf.math.top_k(tf.negative(distance), k=1)
      return tf.abs(closest_distance)
    y_equal_source =  tf.math.equal(classes_y, tf.constant(1, dtype=tf.float32))
    y_equal_all_source = tf.reduce_all(y_equal_source, axis=1)
    predictions_source = tf.boolean_mask(predictions, y_equal_all_source)
    y_source = tf.boolean_mask(y, y_equal_all_source)
    d = tf.map_fn(some_function, (predictions_source,y_source), dtype=tf.float32)
    return tf.math.reduce_sum(d)

# %%
def train_step(model, optimizer, x_batch, y_batch, x_train_target, y_train_target, classes_y):

    with tf.GradientTape() as tape:   
      hidden_logits = model(x_batch, training=True)[0]
      hidden_logits_target = model(x_train_target, training=True)[0]
      loss_dist = distance_loss(hidden_logits, y_batch, hidden_logits_target, y_train_target, classes_y)
      logits = model(x_batch, training=True)[1]
      loss_cross = loss_cc(y_batch, logits)
      loss_value = loss_cross + 0.01*loss_dist

    grads = tape.gradient(loss_value, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    # Update training metric.
    train_acc_metric(y_batch, logits)
    return loss_value, loss_dist, loss_cross

# %%
if loadModelBool:
  model = tf.keras.models.load_model('drive/My Drive/saved_model/svhnmnistm_model')
  dist_losses = load('drive/My Drive/Data/svhnmnistm_model_dist_losses.npy').tolist()
  train_accuracy = load('drive/My Drive/Data/svhnmnistm_model_train_accuracy.npy').tolist()
  cross_entropy_losses = load('drive/My Drive/Data/svhnmnistm_model_cross_entropy_losses.npy').tolist()
  val_accuracy = load('drive/My Drive/Data/svhnmnistm_model_val_accuracy.npy').tolist()
else:
  dist_losses = []
  train_accuracy = []
  cross_entropy_losses = []
  val_accuracy = []

# %%
for epoch in range(num_epochs):
    print('Start of epoch %d' % (epoch,))
    # Iterate over the batches of the dataset.
    step = 0

    for (x_batch, y_batch) in train_dataset:
      
      classes_y = tf.cast(tf.strided_slice(tf.identity(y_batch), [0,-1], [y_batch.shape[0],y_batch.shape[0]], [1,1]),dtype=tf.float32)
      y_batch_ = tf.cast(tf.strided_slice(tf.identity(y_batch), [0,0], [y_batch.shape[0],-1], [1,1]),dtype=tf.float32)

      loss_value, loss_dist, loss_cross = train_step(model, optimizer, x_batch, y_batch_, tf.constant(x_train_mnistm, dtype=tf.float32), tf.constant(y_train_mnistm, dtype=tf.float32), classes_y)

      # Log every 250 batches.
      if step % 250 == 0:
        print('Training loss (for one batch) at step %s: %s' % (step, float(loss_value)))
        print('Distance loss and cross entropy loss at step %s: %s  %s' % (step, float(loss_dist),float(loss_cross)))

      step +=1
    
    dist_losses.append(float(loss_dist))
    cross_entropy_losses.append(float(loss_cross))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print('Training acc over epoch: %s' % (float(train_acc),))
    train_accuracy.append(float(train_acc))

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        val_logits = model(x_batch_val)[1]
        # Update val metrics
        val_acc_metric(y_batch_val, val_logits)
    val_acc = val_acc_metric.result()
    print('Validation acc: %s' % (float(val_acc),))
    val_accuracy.append(float(val_acc))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()
    val_acc_metric.reset_states()
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 1.6552091836929321
# Distance loss and cross entropy loss at step 0: 9.853458404541016  1.556674599647522
# Training loss (for one batch) at step 250: 1.7643529176712036
# Distance loss and cross entropy loss at step 250: 10.682001113891602  1.6575329303741455
# Training loss (for one batch) at step 500: 1.8111903667449951
# Distance loss and cross entropy loss at step 500: 13.702553749084473  1.6741647720336914
# Training loss (for one batch) at step 750: 1.7659454345703125
# Distance loss and cross entropy loss at step 750: 9.404083251953125  1.6719045639038086
# Training loss (for one batch) at step 1000: 1.7745475769042969
# Distance loss and cross entropy loss at step 1000: 13.637372970581055  1.6381738185882568
# Training loss (for one batch) at step 1250: 1.5749502182006836
# Distance loss and cross entropy loss at step 1250: 6.117527961730957  1.5137749910354614
# Training acc over epoch: 0.8519151210784912
# Validation acc: 0.6709520816802979
# Start of epoch 1
# Training loss (for one batch) at step 0: 1.804839015007019
# Distance loss and cross entropy loss at step 0: 9.322831153869629  1.7116106748580933
# Training loss (for one batch) at step 250: 1.6796869039535522
# Distance loss and cross entropy loss at step 250: 7.381049156188965  1.6058764457702637
# Training loss (for one batch) at step 500: 1.6472088098526
# Distance loss and cross entropy loss at step 500: 8.647430419921875  1.560734510421753
# Training loss (for one batch) at step 750: 1.5991586446762085
# Distance loss and cross entropy loss at step 750: 3.8957953453063965  1.5602006912231445
# Training loss (for one batch) at step 1000: 1.6661182641983032
# Distance loss and cross entropy loss at step 1000: 5.4476213455200195  1.6116420030593872
# Training loss (for one batch) at step 1250: 1.6979680061340332
# Distance loss and cross entropy loss at step 1250: 7.602708339691162  1.6219409704208374
# Training acc over epoch: 0.8616935014724731
# Validation acc: 0.6885936856269836

# %%
if saveModelBool:
  model.save('drive/My Drive/saved_model/svhnmnistm_model') 
  save('drive/My Drive/Data/svhnmnistm_model_train_accuracy.npy', train_accuracy)
  save('drive/My Drive/Data/svhnmnistm_model_dist_losses.npy', dist_losses)
  save('drive/My Drive/Data/svhnmnistm_model_cross_entropy_losses.npy', cross_entropy_losses)
  save('drive/My Drive/Data/svhnmnistm_model_val_accuracy.npy', val_accuracy)
# Out:
# INFO:tensorflow:Assets written to: drive/My Drive/saved_model/svhnmnistm_model/assets

# %%
plt.plot(dist_losses)
plt.plot(cross_entropy_losses)
plt.ylabel('loss')
plt.xlabel('batches')
plt.legend(['dist_loss', 'cross_entropy_loss'], loc='best')
plt.show()

# %%
plt.plot(cross_entropy_losses)
plt.ylabel('loss')
plt.xlabel('batches')
plt.show()

# %%
plt.plot(train_accuracy)
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.show()

# %%
# retrain last layer on SVHN and MNIST-M digits and test on MNIST
model_new = keras.models.clone_model(model)
model_new.set_weights(model.get_weights()) 

model_new._layers.pop()
for layer in model_new.layers: layer.trainable = False  

# recover the output from the last layer in the model and use as input to new Dense layer
last = model_new.layers[-1].output
output = keras.layers.Dense(num_classes, activation="softmax", name="output")(last)
model_new = keras.models.Model(model_new.input, output)

for layer in model_new.layers:
    print(layer, layer.trainable)

model_new.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

model_new.summary()

history = model_new.fit(np.concatenate([x_train_svhn, x_train_mnistm], axis=0), np.concatenate([y_train_svhn, y_train_mnistm],axis=0), validation_data = (np.concatenate([x_val_svhn, x_mnistm_test], axis=0), np.concatenate([y_val_svhn,y_mnistm_test],axis=0)), epochs=5,
    shuffle=True,
    verbose=1)

score = model_new.evaluate(x_test_mnist, y_test_mnist, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f47900bd8d0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f47900bdc88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4790434080> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f47901ef5f8> False
# <tensorflow.python.keras.layers.core.Dropout object at 0x7f47901efda0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f47901ef9e8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f47901eff60> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f47901ef978> False
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f479041d0f0> False
# <tensorflow.python.keras.layers.core.Dense object at 0x7f479041d9b0> False
# <tensorflow.python.keras.layers.core.Dense object at 0x7f47900bd7f0> True
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                32020
# _________________________________________________________________
# output (Dense)               (None, 10)                210
# =================================================================
# Total params: 97,798
# Trainable params: 210
# Non-trainable params: 97,588
# _________________________________________________________________
# Epoch 1/5
# 2196/2196 [==============================] - 14s 6ms/step - loss: 0.9814 - accuracy: 0.7509 - val_loss: 1.0988 - val_accuracy: 0.6807
# Epoch 2/5
# 2196/2196 [==============================] - 14s 6ms/step - loss: 0.5661 - accuracy: 0.8480 - val_loss: 1.1173 - val_accuracy: 0.6883
# Epoch 3/5
# 2196/2196 [==============================] - 14s 6ms/step - loss: 0.5429 - accuracy: 0.8511 - val_loss: 1.1364 - val_accuracy: 0.6891
# Epoch 4/5
# 2196/2196 [==============================] - 14s 6ms/step - loss: 0.5376 - accuracy: 0.8534 - val_loss: 1.1415 - val_accuracy: 0.6896
# Epoch 5/5
# 2196/2196 [==============================] - 14s 6ms/step - loss: 0.5354 - accuracy: 0.8539 - val_loss: 1.1499 - val_accuracy: 0.6897
# Test loss: 4.347341060638428
# Test accuracy: 0.11349999904632568

# %%
score = model_new.evaluate(x_mnistm_test, y_mnistm_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.4964522123336792
# Test accuracy: 0.5984890460968018

# %%
layer_of_interest=3
intermediate_layer_model = keras.models.Model(inputs=model_new.input,
                                 outputs=model_new.get_layer("dense_1").output)
intermediates = intermediate_layer_model.predict(np.concatenate([x_val_svhn, x_mnistm_test], axis=0))
colors = ["blue", "green", "red", "yellow", "orange", "grey", "black", "pink", "purple", "brown"]
color_intermediates = np.array(colors)[np.argmax(np.concatenate([y_val_svhn,y_mnistm_test],axis=0), axis=1)]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
intermediates_tsne = tsne.fit_transform(intermediates)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(x = intermediates_tsne[:,0], y=intermediates_tsne[:,1], facecolors='none', edgecolors=color_intermediates)
plt.show()

# %%
labels = np.concatenate((y_train_svhn_ones.flatten(
),y_train_mnist_zeros.flatten())).astype(int)

# %%
colors = ["blue", "red"]
color_intermediates = np.array(colors)[labels]
plt.figure(figsize=(8, 8))
plt.scatter(x = intermediates_tsne[:,0], y=intermediates_tsne[:,1], facecolors='none', edgecolors=color_intermediates)
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy', 'val_accuracy'], loc='best')
plt.show()
